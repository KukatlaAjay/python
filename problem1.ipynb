# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 s="1 2 3"
# ----> 2 print(int(s))
#
# ValueError: invalid literal for int() with base 10: '1 2 3'

# %%
readings=int(input("enter readings"))
lst=[]
sum=0
for i in range(0,readings):
    values=int(input("enter the values"))
    lst.append(values)
max=int(input("enter the max"))
print(lst)
for i in range(0,values):
    sub1=[]
    sub1.append(i)
    if len(sub1)==max:
        break
for i in sub1:
    sum=0
    sum=sum+i
print(sum)
for i in range(0,values):
    sub2=[]
    sub2.append(i)
    if len(sub1)==max:
        break
for i in sub2:
    sum1=0
    sum1=sum1+i
print(sum2)
# Out:
# enter readings 6
# enter the values 3
# enter the values 5
# enter the values 4
# enter the values 5
# enter the values 4
# enter the values 3
# enter the max 3
# [3, 5, 4, 5, 4, 3]
# 2

# %%
string=input("enter the string")
count=""
for i in range(0,len(string)):
    for j in range(i+1,string):
        if string[i]==string[j]:
            count=count+string[i]
            
print(len(count))
# Out:
# enter the string abcabc
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 count=""
#       3 for i in range(0,len(string)):
# ----> 4     for j in range(i+1,string):
#       5         if string[i]==string[j]:
#       6             count=count+string[i]
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
n=int(input("enter the number"))
for i in range(0,n):
    start=int(input("Enter the number"))
    end=int(input("enter the number"))
